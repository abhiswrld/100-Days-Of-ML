# %% [markdown]
# ## Pipelines chain together multiple steps so that the output of each step is used as input for the next
#
# ## Pipelines also makes it easy for us to apply the same preprocessing to the train and test set
#
# <p> There will be 3 total notebooks in this day, and this notebook ends here.
